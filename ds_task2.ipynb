# %% [markdown]
# <a href="https://colab.research.google.com/github/Btexxx/Bharat-Intern/blob/main/ds_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df= pd.read_csv("Tiata dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['PassengerId']=pd.to_datetime(df['PassengerId'])

# %%
df.head()
# Out:
#                     PassengerId  Survived  Pclass  \
# 0 1970-01-01 00:00:00.000000001         0       3
# 1 1970-01-01 00:00:00.000000002         1       1
# 2 1970-01-01 00:00:00.000000003         1       3
# 3 1970-01-01 00:00:00.000000004         1       1
# 4 1970-01-01 00:00:00.000000005         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.fillna({'PassengerId':'unavailable','Pclass':'unavailable','Parch':'unavailable','Embarked':'unavailable','Survived':'unavailable'},inplace=True)
df.isnull().sum()
# Out:
# <ipython-input-70-5d0c37ef7abf>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.fillna({'PassengerId':'unavailable','Pclass':'unavailable','Parch':'unavailable','Embarked':'unavailable','Survived':'unavailable'},inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df_num = df[['Age','Parch','SibSp','Fare']]
df_cat = df[['Sex','Name','Ticket' ,'Embarked','Pclass','Cabin']]

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
sns.heatmap(df_num.corr())
# Out:
# <Axes: >

# %%
 pd.pivot_table(df , index = 'Survived' ,values= ['Age','Parch','SibSp','Fare'])
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
print(pd.pivot_table(df,index='Survived' ,columns='Pclass' ,values='Ticket',aggfunc='count'))
print()
print(pd.pivot_table(df,index='Survived' ,columns='Age' ,values='Ticket',aggfunc='count'))
print()
print(pd.pivot_table(df,index='Survived' ,columns='Embarked' ,values='Ticket',aggfunc='count'))
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
#
# Age       0.42   0.67   0.75   0.83   0.92   1.00   2.00   3.00   4.00   \
# Survived
# 0           NaN    NaN    NaN    NaN    NaN    2.0    7.0    1.0    3.0
# 1           1.0    1.0    2.0    2.0    1.0    5.0    3.0    5.0    7.0
#
# Age       5.00   ...  62.00  63.00  64.00  65.00  66.00  70.00  70.50  71.00  \
# Survived         ...
# 0           NaN  ...    2.0    NaN    2.0    3.0    1.0    2.0    1.0    2.0
# 1           4.0  ...    2.0    2.0    NaN    NaN    NaN    NaN    NaN    NaN
#
# Age       74.00  80.00
# Survived
# 0           1.0    NaN
# 1           NaN    1.0
#
# [2 rows x 88 columns]
#
# Embarked     C     Q      S  unavailable
# Survived
# 0         75.0  47.0  427.0          NaN
# 1         93.0  30.0  217.0          2.0

# %%
df_cat.Cabin
df['Cabin_multiple'] = df.Cabin.apply(lambda x:0 if pd.isna(x)
else len(x.split('')))
df['Cabin_multiple'].value_counts()
# Out:
# 0    687
# 1    180
# 2     16
# 3      6
# 4      2
# Name: Cabin_multiple, dtype: int64

# %%
pd.pivot_table(df,index='Survived' ,columns='Cabin_multiple' ,values='Ticket',aggfunc='count')
# Out:
# Cabin_multiple    A     B     C     D     E    F    G    T      n
# Survived
# 0               8.0  12.0  24.0   8.0   8.0  5.0  2.0  1.0  481.0
# 1               7.0  35.0  35.0  25.0  24.0  8.0  2.0  NaN  206.0

# %%
df['Cabin_adv'] = df.Cabin.apply(lambda x: str(x)[0])
print(df.Cabin_adv.value_counts())
pd.pivot_table(df,index='Survived' ,columns='Cabin_adv' ,values='Ticket',aggfunc='count')
# Out:
# n    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin_adv, dtype: int64
# Cabin_adv    A     B     C     D     E    F    G    T      n
# Survived
# 0          8.0  12.0  24.0   8.0   8.0  5.0  2.0  1.0  481.0
# 1          7.0  35.0  35.0  25.0  24.0  8.0  2.0  NaN  206.0

# %%
df.Name.head(60)
df['Name_title']=df.Name.apply(lambda x:x.split(',')[1].split('.')[0].strip(''))
df['Name_title'].value_counts()
# Out:
#  Mr              517
#  Miss            182
#  Mrs             125
#  Master           40
#  Dr                7
#  Rev               6
#  Mlle              2
#  Major             2
#  Col               2
#  the Countess      1
#  Capt              1
#  Ms                1
#  Sir               1
#  Lady              1
#  Mme               1
#  Don               1
#  Jonkheer          1
# Name: Name_title, dtype: int64
